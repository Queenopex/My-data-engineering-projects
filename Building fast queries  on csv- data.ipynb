# %% [markdown]
# The goal of this guided project is to create a class that represents our inventory. The methods in that class will implement the queries that we want to answer about our inventory. We will also preprocess that data to make those queries run faster.

# %%
import csv
opened_file = open('laptops.csv')
read_file = csv.reader(opened_file)
laptops = list(read_file)
header = laptops[0]
rows = laptops[1:]
print(header)
print('\n')
print(rows[:5])
# Out:
# ['Id', 'Company', 'Product', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price']
#
#
# [['6571244', 'Apple', 'MacBook Pro', 'Ultrabook', '13.3', 'IPS Panel Retina Display 2560x1600', 'Intel Core i5 2.3GHz', '8GB', '128GB SSD', 'Intel Iris Plus Graphics 640', 'macOS', '1.37kg', '1339'], ['7287764', 'Apple', 'Macbook Air', 'Ultrabook', '13.3', '1440x900', 'Intel Core i5 1.8GHz', '8GB', '128GB Flash Storage', 'Intel HD Graphics 6000', 'macOS', '1.34kg', '898'], ['3362737', 'HP', '250 G6', 'Notebook', '15.6', 'Full HD 1920x1080', 'Intel Core i5 7200U 2.5GHz', '8GB', '256GB SSD', 'Intel HD Graphics 620', 'No OS', '1.86kg', '575'], ['9722156', 'Apple', 'MacBook Pro', 'Ultrabook', '15.4', 'IPS Panel Retina Display 2880x1800', 'Intel Core i7 2.7GHz', '16GB', '512GB SSD', 'AMD Radeon Pro 455', 'macOS', '1.83kg', '2537'], ['8550527', 'Apple', 'MacBook Pro', 'Ultrabook', '13.3', 'IPS Panel Retina Display 2560x1600', 'Intel Core i5 3.1GHz', '8GB', '256GB SSD', 'Intel Iris Plus Graphics 650', 'macOS', '1.37kg', '1803']]

# %% [markdown]
# We will be creating a class called inventory, it will take the name of the CSV file as argument and then the rows contained iin it.

# %%
import csv

#creating the inventory class
class Inventory():
    def __init__(self, csv_filename):
        with open(csv_filename) as f:
            reader = csv.reader(f)
            rows = list(reader)
        self.header = rows[0]
        self.rows = rows[1:]
        for price in self.rows:
            price[-1] = int(price[-1])
            
            
#testing the inventory class            
inventory = Inventory('laptops.csv')
print(inventory.header)
print(len(inventory.rows))
# Out:
# ['Id', 'Company', 'Product', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price']
# 1303

# %% [markdown]
# We will write a new function name get_laptop from_id. This function will take argument the identifier of the laptop and return the full row of the laptop with that id.

# %%
import csv

class Inventory():
    def __init__(self, csv_filename):
        with open(csv_filename) as f:
            reader = csv.reader(f)
            rows = list(reader)
        self.header = rows[0]
        self.rows = rows[1:]
        for price in self.rows:
            price[-1] = int(price[-1])
            
    def get_laptop_from_id(self, laptop_id):
        for row in self.rows:
            if row[0] == laptop_id:
                return row
            
        return None

#testing the inventory class
inventory = Inventory('laptops.csv')
print(inventory.get_laptop_from_id('3362737'))
print(inventory.get_laptop_from_id('3362736'))
# Out:
# ['3362737', 'HP', '250 G6', 'Notebook', '15.6', 'Full HD 1920x1080', 'Intel Core i5 7200U 2.5GHz', '8GB', '256GB SSD', 'Intel HD Graphics 620', 'No OS', '1.86kg', 575]
# None

# %%
import csv

class Inventory():
    def __init__(self, csv_filename):
        with open(csv_filename) as f:
            reader = csv.reader(f)
            rows = list(reader) 
        
        self.header = rows[0]
        self.rows = rows[1:]
        for price in self.rows:
            price[-1] = int(price[-1])
            
        self.id_to_row = {}
        for row in self.rows:
            self.id_to_row[row[0]] = row 
            
    def get_laptop_from_id(self, laptop_id):
        for row in self.rows:
            if row[0] == laptop_id:
                return row
        return None
    
    def get_laptop_from_id_fast(self, laptop_id):
        if laptop_id in self.id_to_row:
            return self.id_to_row[laptop_id] ## added self. at the start
        return None
            
#testing the inventory class

inventory = Inventory('laptops.csv')
print(inventory.get_laptop_from_id_fast('3362737'))
print(inventory.get_laptop_from_id_fast('3362736'))
### the issues was that self_id_to_row was not assigne to any
### instance of variable
# Out:
# ['3362737', 'HP', '250 G6', 'Notebook', '15.6', 'Full HD 1920x1080', 'Intel Core i5 7200U 2.5GHz', '8GB', '256GB SSD', 'Intel HD Graphics 620', 'No OS', '1.86kg', 575]
# None

# %%
import time
import random

ids= [str(random.randint(1000000, 10000000)) for _ in range(10000)]


inventory = Inventory('laptops.csv')

total_time_no_dict = 0
for i in ids:
    start = time.time()
    inventory.get_laptop_from_id(i)
    end = time.time()
    total_time_no_dict += (end-start)
    
    
total_time_dict = 0
for i in ids:
    start = time.time()
    inventory.get_laptop_from_id_fast(i)
    end = time.time()
    total_time_dict += (end - start)

    
print(total_time_no_dict)
print(total_time_dict)
# Out:
# 1.5255906581878662
# 0.005940914154052734

# %%
class Inventory():
    def __init__(self, csv_filename):
        with open(csv_filename) as f:
            reader = csv.reader(f)
            rows = list(reader) 
        
        self.header = rows[0]
        self.rows = rows[1:]
        for price in self.rows:
            price[-1] = int(price[-1])
            
        self.id_to_row = {}
        for row in self.rows:
            self.id_to_row[row[0]] = row 
            
    def get_laptop_from_id(self, laptop_id):
        for row in self.rows:
            if row[0] == laptop_id:
                return row
        return None
    
    def get_laptop_from_id_fast(self, laptop_id):
        if laptop_id in self.id_to_row:
            return self.id_to_row[laptop_id]
        return None
    
    def check_promotion_dollars(self, dollars):
        for row in self.rows:
            if row[-1] == dollars:
                return True
        for row1 in self.rows:
            for row2 in self.rows:
                if row1[-1] + row2[-1]== dollars:
                    return True
        return False
    
inventory = Inventory('laptops.csv')
print(inventory.check_promotion_dollars(1000))
print(inventory.check_promotion_dollars(442))
# Out:
# True
# False

# %%
class Inventory():
    def __init__(self, csv_filename):
        with open(csv_filename) as f:
            reader = csv.reader(f)
            rows = list(reader) 
        
        self.header = rows[0]
        self.rows = rows[1:]
        for price in self.rows:
            price[-1] = int(price[-1])
            
        self.id_to_row = {}
        for row in self.rows:
            self.id_to_row[row[0]] = row 
            
        self.prices = set()
        for row in self.prices:
            self.prices.add(row[-1])
        
    def get_laptop_from_id(self, laptop_id):
        for row in self.rows:
            if row[0] == laptop_id:
                return row
        return None
    
    def get_laptop_from_id_fast(self, laptop_id):
        if laptop_id in self.id_to_row:
            return self.id_to_row[laptop_id]
        return None
    
    def check_promotion_dollars(self, dollars):
        for row in self.rows:
            if row[-1] == dollars:
                return True
        for row1 in self.rows:
            for row2 in self.rows:
                if row1[-1] + row2[-1]== dollars:
                    return True
        return False
    
    def check_promotion_dollars_fast(self, dollars):
        for row in self.prices:
            if row[-1] == dollars:
                return True
        for row1 in self.rows:
            for row2 in self.rows:
                if row1[-1] + row2[-1] == dollars:
                    return True
        return False

    
inventory = Inventory('laptops.csv')
print(inventory.check_promotion_dollars_fast(1000))
print(inventory.check_promotion_dollars_fast(442))
# Out:
# True
# False

# %%
prices=[str(random.randint(100, 5000)) for _ in range(100)]
        
inventory = Inventory('laptops.csv')

total_time_no_set = 0

for price in prices:
    start = time.time()
    inventory.check_promotion_dollars(price)
    end = time.time()
    total_time_no_set += end - start
        
tota_time_set = 0
        
for price in prices:
        start = time.time()
        inventory.check_promotion_dollars_fast(price)
        end = time.time()
        total_time_set += end - start
        
print(total_time_no_set)
print(total_time_set)
# Out:
# 36.63568663597107
# 115.94882130622864

# %%
class Inventory():
    def __init__(self, csv_filename):
        with open(csv_filename) as f:
            reader = csv.reader(f)
            rows = list(reader) 
        
        self.header = rows[0]
        self.rows = rows[1:]
        for price in self.rows:
            price[-1] = int(price[-1])
            
        self.id_to_row = {}
        for row in self.rows:
            self.id_to_row[row[0]] = row 
            
        self.prices = set()
        for row in self.prices:
            self.prices.add(row[-1])
            
        self.rows_by_price = sorted(self.rows, key= row_price)
        
    def get_laptop_from_id(self, laptop_id):
        for row in self.rows:
            if row[0] == laptop_id:
                return row
        return None
    
    def get_laptop_from_id_fast(self, laptop_id):
        if laptop_id in self.id_to_row:
            return self.id_to_row[laptop_id]
        return None
    
    def check_promotion_dollars(self, dollars):
        for row in self.rows:
            if row[-1] == dollars:
                return True
        for row1 in self.rows:
            for row2 in self.rows:
                if row1[-1] + row2[-1]== dollars:
                    return True
        return False
    
    def check_promotion_dollars_fast(self, dollars):
        for row in self.prices:
            if row[-1] == dollars:
                return True
        for row1 in self.rows:
            for row2 in self.rows:
                if row1[-1] + row2[-1] == dollars:
                    return True
        return False
    def find_laptop_with_price(self, target_price):
    range_start = 0                                   
    range_end = len(self.rows_by_price) - 1                       
    while range_start < range_end:
        range_middle = (range_end + range_start) // 2  
        price = self.rows_by_price[range_middle][-1]
        if price == target_price:                            
            return range_middle                        
        elif price < target_price:                           
            range_start = range_middle + 1             
        else:                                          
            range_end = range_middle - 1 
    price = self.rows_by_price[range_start][-1]
    if price != target_price:                  
        return -1                                      
    return range_start
    
    
    def find_first_laptop_more_expensive(self, price):
        range_start = 0                                   
        range_end = len(self.rows_by_price) - 1                       
        while range_start < range_end:
            range_middle = (range_end + range_start) // 2  
            price = self.rows_by_price[range_middle][-1]
            if price == target_price:                            
                return range_middle                        
            elif price < target_price:                           
                range_start = range_middle + 1             
            else:                                          
                range_end = range_middle - 1 
        price = self.rows_by_price[range_start][-1]
        if price >= target_price:                  
            return -1                                      
        return range_start
    

inventory = Inventory('laptop.csv')
print(inventory.find_first_laptop_more_expensive(1000))
print(inventory.find_first_laptop_more_expensive(10000))
# Out:
#   File "<ipython-input-3-e2d6f47ef6f4>", line 53
#     range_start = 0
#     ^
# IndentationError: expected an indented block

# %%
class Inventory():
    def __init__(self, csv_filename):
        with open(csv_filename) as f:
            reader = csv.reader(f)
            rows = list(reader) 
        
        self.header = rows[0]
        self.rows = rows[1:]
        for price in self.rows:
            price[-1] = int(price[-1])
            
        self.id_to_row = {}
        for row in self.rows:
            self.id_to_row[row[0]] = row 
            
        self.prices = set()
        for row in self.prices:
            self.prices.add(row[-1])
            
        self.rows_by_price = sorted(self.rows, key= row_price)
        
    def get_laptop_from_id(self, laptop_id):
        for row in self.rows:
            if row[0] == laptop_id:
                return row
        return None
    
    def get_laptop_from_id_fast(self, laptop_id):
        if laptop_id in self.id_to_row:
            return self.id_to_row[laptop_id]
        return None
    
    def check_promotion_dollars(self, dollars):
        for row in self.rows:
            if row[-1] == dollars:
                return True
        for row1 in self.rows:
            for row2 in self.rows:
                if row1[-1] + row2[-1]== dollars:
                    return True
        return False
    
    def check_promotion_dollars_fast(self, dollars):
        for row in self.prices:
            if row[-1] == dollars:
                return True
        for row1 in self.rows:
            for row2 in self.rows:
                if row1[-1] + row2[-1] == dollars:
                    return True
        return False
    def find_laptop_with_price(self, target_price):
    range_start = 0                                   
    range_end = len(self.rows_by_price) - 1                       
    while range_start < range_end:
        range_middle = (range_end + range_start) // 2  
        price = self.rows_by_price[range_middle][-1]
        if price == target_price:                            
            return range_middle                        
        elif price < target_price:                           
            range_start = range_middle + 1             
        else:                                          
            range_end = range_middle - 1 
    price = self.rows_by_price[range_start][-1]
    if price != target_price:                  
        return -1                                      
    return range_start
    
    
    def find_first_laptop_more_expensive(self, price):
        range_start = 0                                   
        range_end = len(self.rows_by_price) - 1                       
        while range_start < range_end:
            range_middle = (range_end + range_start) // 2  
            price = self.rows_by_price[range_middle][-1]
            if price == target_price:                            
                return range_middle                        
            elif price < target_price:                           
                range_start = range_middle + 1             
            else:                                          
                range_end = range_middle - 1 
        price = self.rows_by_price[range_start][-1]
        if price >= target_price:                  
            return -1                                      
        return range_start
    

inventory = Inventory('laptop.csv')
print(inventory.find_first_laptop_more_expensive(1000))
print(inventory.find_first_laptop_more_expensive(10000))
# Out:
#   File "<ipython-input-6-20ec866ec373>", line 53
#     range_start = 0
#     ^
# IndentationError: expected an indented block

# %%
import csv

class Inventory():
    def __init__(self, csv_filename):
        with open(csv_filename) as f:
            reader = csv.reader(f)
            rows = list(reader) 
        
        self.header = rows[0]
        self.rows = rows[1:]
        for price in self.rows:
            price[-1] = int(price[-1])
            
        self.id_to_row = {}
        for row in self.rows:
            self.id_to_row[row[0]] = row 
            
        self.prices = set()
        for row in self.rows:
            self.prices.add(row[-1])
            
        self.rows_by_price = sorted(self.rows, key=lambda row: row[-1])
        
    def get_laptop_from_id(self, laptop_id):
        for row in self.rows:
            if row[0] == laptop_id:
                return row
        return None
    
    def get_laptop_from_id_fast(self, laptop_id):
        if laptop_id in self.id_to_row:
            return self.id_to_row[laptop_id]
        return None
    
    def check_promotion_dollars(self, dollars):
        for row in self.rows:
            if row[-1] == dollars:
                return True
        for row1 in self.rows:
            for row2 in self.rows:
                if row1[-1] + row2[-1]== dollars:
                    return True
        return False
    
    def check_promotion_dollars_fast(self, dollars):
        for row in self.rows:
            if row[-1] == dollars:
                return True
        for row1 in self.rows:
            for row2 in self.rows:
                if row1[-1] + row2[-1] == dollars:
                    return True
        return False
    
    def find_laptop_with_price(self, target_price):
        range_start = 0                                   
        range_end = len(self.rows_by_price) - 1                       
        while range_start < range_end:
            range_middle = (range_end + range_start) // 2  
            price = self.rows_by_price[range_middle][-1]
            if price == target_price:                            
                return range_middle                        
            elif price < target_price:                           
                range_start = range_middle + 1             
            else:                                          
                range_end = range_middle - 1 
        price = self.rows_by_price[range_start][-1]
        if price != target_price:                  
            return -1                                      
        return range_start
    
    
    def find_first_laptop_more_expensive(self, target_price):
        range_start = 0
        range_end = len(self.rows_by_price) - 1
        found_price = self.rows_by_price[range_end][-1]
        if found_price < target_price:
            return -1
        while range_start < range_end:
            range_middle = (range_end + range_start) // 2
            found_price = self.rows_by_price[range_middle][-1]
            if found_price == target_price:
                return range_middle + 1
            elif found_price < target_price:
                range_start = range_middle + 1
            else:
                range_end = range_middle
        return range_end + 1

# %%
inventory = Inventory('laptops.csv')
print(inventory.find_first_laptop_more_expensive(1000))
print(inventory.find_first_laptop_more_expensive(10000))
# Out:
# 683
# -1

# %%
import csv

class Inventory():
    def __init__(self, csv_filename):
        with open(csv_filename) as f:
            reader = csv.reader(f)
            rows = list(reader) 
        
        self.header = rows[0]
        self.rows = rows[1:]
        for price in self.rows:
            price[-1] = int(price[-1])
            
        self.id_to_row = {}
        for row in self.rows:
            self.id_to_row[row[0]] = row 
            
        self.prices = set()
        for row in self.rows:
            self.prices.add(row[-1])
            
        self.rows_by_price = sorted(self.rows, key=lambda row: row[-1])
        
    def get_laptop_from_id(self, laptop_id):
        for row in self.rows:
            if row[0] == laptop_id:
                return row
        return None
    
    def get_laptop_from_id_fast(self, laptop_id):
        if laptop_id in self.id_to_row:
            return self.id_to_row[laptop_id]
        return None
    
    def check_promotion_dollars(self, dollars):
        for row in self.rows:
            if row[-1] == dollars:
                return True
        for row1 in self.rows:
            for row2 in self.rows:
                if row1[-1] + row2[-1]== dollars:
                    return True
        return False
    
    def check_promotion_dollars_fast(self, dollars):
        for row in self.rows:
            if row[-1] == dollars:
                return True
        for row1 in self.rows:
            for row2 in self.rows:
                if row1[-1] + row2[-1] == dollars:
                    return True
        return False
    
    def find_laptop_with_price(self, target_price):
        range_start = 0                                   
        range_end = len(self.rows_by_price) - 1                       
        while range_start < range_end:
            range_middle = (range_end + range_start) // 2  
            price = self.rows_by_price[range_middle][-1]
            if price == target_price:                            
                return range_middle                        
            elif price < target_price:                           
                range_start = range_middle + 1             
            else:                                          
                range_end = range_middle - 1 
        price = self.rows_by_price[range_start][-1]
        if price != target_price:                  
            return -1                                      
        return range_start
    
    
    def find_first_laptop_more_expensive(self, target_price):
        range_start = 0
        range_end = len(self.rows_by_price) - 1
        found_price = self.rows_by_price[range_end][-1]
        if found_price < target_price:
            return -1
        while range_start < range_end:
            range_middle = (range_end + range_start) // 2
            found_price = self.rows_by_price[range_middle][-1]
            if found_price == target_price:
                return range_middle + 1
            elif found_price < target_price:
                range_start = range_middle + 1
            else:
                range_end = range_middle
        return range_end + 1

    
    def find_laptop_in_price_range(self,min_price,max_price):
        laptops = []
        for row in self.rows:
            price = row[-1]
            if price >= min_price and price <= max_price:
                laptops.append(row)
        return laptops
    
inventory = Inventory('laptops.csv')
print(inventory.find_laptop_in_price_range(1000, 2000)[:3])
# Out:
# [['6571244', 'Apple', 'MacBook Pro', 'Ultrabook', '13.3', 'IPS Panel Retina Display 2560x1600', 'Intel Core i5 2.3GHz', '8GB', '128GB SSD', 'Intel Iris Plus Graphics 640', 'macOS', '1.37kg', 1339], ['8550527', 'Apple', 'MacBook Pro', 'Ultrabook', '13.3', 'IPS Panel Retina Display 2560x1600', 'Intel Core i5 3.1GHz', '8GB', '256GB SSD', 'Intel Iris Plus Graphics 650', 'macOS', '1.37kg', 1803], ['3824690', 'Apple', 'Macbook Air', 'Ultrabook', '13.3', '1440x900', 'Intel Core i5 1.8GHz', '8GB', '256GB Flash Storage', 'Intel HD Graphics 6000', 'macOS', '1.34kg', 1158]]
